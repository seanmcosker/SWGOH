# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
os.environ['TOKEN'] = "AAAAAAAAAAAAAAAAAAAAAAs0ggEAAAAAZa1IS2xF3DqB4kIElAFDyc6oyZM%3DKaJowQh3hk4sqf8b8Lb3DrlffIBE7wDWoTrbTQNrGI4tbaqXRz"

# %%
def auth():
    return os.getenv('TOKEN')

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

def create_url(keyword, max_results = 50):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    #'start_time': start_date,
                    #'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "SWGOH lang:en"
start_time = "2022-01-01T00:00:00.000Z"
end_time = "2021-08-29T00:00:00.000Z"
max_results = 50

# %%
url = create_url(keyword)
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 200

# %%
tweets = []
for i in range((50)):
    try:
        tweets.append(json_response["data"][i]["text"])
    except IndexError:
        break

# %%
tweets
# Out:
# ["The next Smuggler's Run II will be 2022-11-05 #swgoh #events https://t.co/GNphNMDRbc",
#  'With a free calendar in #SWGoH featuring Wrecker and Hunter as the standard login character, I have to think a #BadBatch character is incoming this month. Crosshair is the obvious one, but who else would make sense?',
#  'Come check out my first #SWGoH fleet arena climb with Profundity! https://t.co/TUoWx8I0eG',
#  '@EAHelp errorcode 3.0 on SWGOH, both on tablet and phone.',
#  'Scythe (hard) Conquest sector 1 feats guide - SWGOH https://t.co/Eo6CeokDor via @YouTube',
#  "I went 3-6 in this #SWGoH GAC season. My opponents' GP advantage were as follows: +1.7MM, +0.2MM, +0.7MM, +1.1MM, +1.2MM, -0.6MM, +1.1MM, +1.7MM, +1.4MM\nSo 3 wins and 3 opponents within 1MM GP of my account. Can't ask for more than that... Except an actual matchmaking system, CG!",
#  'StarkSG is LIVE!! join us on twitch for SWGOH GAC, strategy discussion, and more! https://t.co/YBkjz6cxW3',
#  '*Cough cough* let’s do this *cough cough* #SWGoH #swgoh #gaming #SWGOH #twitch #streaming #GAC #swgohgac\n\nhttps://t.co/PPIqYPJq81',
#  "After another 2.5 hrs, finally got Profundity 7 star. Thank god that's over! #SWGoH https://t.co/FHJS3Xbzl1",
#  'Finally unlocked Profundity! If u want it, be prepare for #SWGoH rng 💩 show. Took me 3 hrs to unlock. Now need to do bonus tier... https://t.co/I7LBujoMMv',
#  'JMK Destroys Rey/Dash/Ben Solo with datacron! - SWGOH - Grand arena https://t.co/3umdZmafjw via @YouTube',
#  'StarkSG is LIVE!! join us on twitch for SWGOH GAC, strategy discussion, and more! https://t.co/YBkjz6cxW3',
#  "@DwarfMaul2 @OGStarwarsAB I'm curious whats SWGOH? I can guess another Star Wars Galaxies emu server but haven't seen that acronym for one yet.",
#  'The next Credit Heist will be 2022-11-01 #swgoh #events https://t.co/7YOfLoJVmr',
#  'The #GAC it’s super fun when you have to face a guy with almost 4.5 Million GP … thank you @ea_capitalgames @EA please fix the matchmaking 🙏🏻 #SWGoH https://t.co/FXl9kzjebW',
#  '@MLGPROX @AzezelFallen @Diablo And try buy all content to max level is SWGoH or Marvel Strike Force? Disney Mirrorverse have more currencies then Immortal and that is game for children 😅 And we can continue...',
#  "@OGStarwarsAB This is actually disgusting. I'm done. I'm gonna keep playing swgoh, battlefront games and reading what I have, but I'm done. Disney can have it.",
#  'DarthJJ will be streaming shortly… as soon as I can heat this milk up for a drink 👀\n\n#SWGoH #swgoh #gaming #SWGOH #twitch #streaming #GAC #swgohgac \nhttps://t.co/PPIqYPJq81 https://t.co/l7MzkZaji1',
#  'Started up a new section of the site for #SWGoH today - the Best Datacrons. Like them or not, Datacrons are here to stay in #GalaxyOfHeroes so we might as well understand and embrace them! https://t.co/UNvOZ9BYMe',
#  'Look I know GAC matchmaking isn’t perfect but what the hell is this? @ea_capitalgames @CubsFanHan (obviously I’m the smaller account) \n\n#SWGOH https://t.co/pnbO5Kg6om',
#  'The next credit heist will be Tuesday, 1st November #swgoh #heists',
#  'The next Credit Heist will be 2022-11-01 #swgoh #events https://t.co/vEnZ3Hs92s',
#  'The struggle is real! #SWGoH https://t.co/X8MHpAPbR0',
#  'Star Wars Galaxy of Heroes - Beginner Guide Part 2 - Continue your journ... https://t.co/vLRJ4Ha5Mo via @YouTube #starwars #SWGoH #galaxyofheroes',
#  'StarkSG is LIVE!! join us on twitch for SWGOH GAC, strategy discussion, and more! https://t.co/YBkjz6cxW3',
#  'RANKING ALL #SWGOH SOLO LEGENDARY TOONS! (Nov 2022) https://t.co/WKJPKqvGn0 via @YouTube',
#  '@mattapodaca @vicmmic It’s fun. Sort of like a Marvel card game version of Bones from Cult of the Lamb. Not nearly as pay to win as say Marvel Strike or SWGOH.',
#  "RT @Mcmole2: There's a growing problem with hacking/cheating in SWGoH, and it's getting worse.  Breaking down the @bulldog1205 video showin…",
#  'Luminara Omicron!!!! - SWGOH - Is it good? https://t.co/zyOhwrMvq2 via @YouTube',
#  'Star Wars Galaxy of Heroes - Beginner Guide Part 1 - How to get started ... https://t.co/w2mJgIzpEH via @YouTube #StarWars #SWGoH #galaxyofheroes',
#  'GRAND ARENA MADE ME WANT TO BREAK MY MONITOR! #swgoh https://t.co/UTD91aAI3e',
#  'StarkSG is LIVE!! join us on twitch for SWGOH GAC, strategy discussion, and more! https://t.co/YBkjz6cxW3',
#  '@Qwik @JHight_Gamer @TheWindstalker Nexus finding another place to consume 😍😍 I need more from Nexus universe - still mobile game variation as SWGoH will be amazing 😍 HotS never die ❤️❤️ Hope announce release dáte for Arclight Rumble 😍',
#  '@Stonekettle SWGOH, F2P, no console needed, building teams based on abilities.',
#  'I took a break from making books to play a bit of #StarWars #swgoh \n\nEnjoy if you’re into this sort of thing. \n\nIt’s no secret Darth Vader is my favorite. \n\nhttps://t.co/pOqJ9msbtI']

# %%
pd.DataFrame(tweets)
# Out:
#                                                     0
# 0   The next Smuggler's Run II will be 2022-11-05 ...
# 1   With a free calendar in #SWGoH featuring Wreck...
# 2   Come check out my first #SWGoH fleet arena cli...
# 3   @EAHelp errorcode 3.0 on SWGOH, both on tablet...
# 4   Scythe (hard) Conquest sector 1 feats guide - ...
# 5   I went 3-6 in this #SWGoH GAC season. My oppon...
# 6   StarkSG is LIVE!! join us on twitch for SWGOH ...
# 7   *Cough cough* let’s do this *cough cough* #SWG...
# 8   After another 2.5 hrs, finally got Profundity ...
# 9   Finally unlocked Profundity! If u want it, be ...
# 10  JMK Destroys Rey/Dash/Ben Solo with datacron! ...
# 11  StarkSG is LIVE!! join us on twitch for SWGOH ...
# 12  @DwarfMaul2 @OGStarwarsAB I'm curious whats SW...
# 13  The next Credit Heist will be 2022-11-01 #swgo...
# 14  The #GAC it’s super fun when you have to face ...
# 15  @MLGPROX @AzezelFallen @Diablo And try buy all...
# 16  @OGStarwarsAB This is actually disgusting. I'm...
# 17  DarthJJ will be streaming shortly… as soon as ...
# 18  Started up a new section of the site for #SWGo...
# 19  Look I know GAC matchmaking isn’t perfect but ...
# 20  The next credit heist will be Tuesday, 1st Nov...
# 21  The next Credit Heist will be 2022-11-01 #swgo...
# 22  The struggle is real! #SWGoH https://t.co/X8MH...
# 23  Star Wars Galaxy of Heroes - Beginner Guide Pa...
# 24  StarkSG is LIVE!! join us on twitch for SWGOH ...
# 25  RANKING ALL #SWGOH SOLO LEGENDARY TOONS! (Nov ...
# 26  @mattapodaca @vicmmic It’s fun. Sort of like a...
# 27  RT @Mcmole2: There's a growing problem with ha...
# 28  Luminara Omicron!!!! - SWGOH - Is it good? htt...
# 29  Star Wars Galaxy of Heroes - Beginner Guide Pa...
# 30  GRAND ARENA MADE ME WANT TO BREAK MY MONITOR! ...
# 31  StarkSG is LIVE!! join us on twitch for SWGOH ...
# 32  @Qwik @JHight_Gamer @TheWindstalker Nexus find...
# 33  @Stonekettle SWGOH, F2P, no console needed, bu...
# 34  I took a break from making books to play a bit...

# %%
import nltk

#nltk.download("vader_lexicon")

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
vds = SentimentIntensityAnalyzer()
text = tweets[0]

print("Sentiment Analysis of text")
vds.polarity_scores(text)
# Out:
# Sentiment Analysis of text
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
for i in tweets:
    print("Tweet: ", i)
    print("Score: ", vds.polarity_scores(i))
    print("********")
# Out:
# Tweet:  The next Smuggler's Run II will be 2022-11-05 #swgoh #events https://t.co/GNphNMDRbc
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  With a free calendar in #SWGoH featuring Wrecker and Hunter as the standard login character, I have to think a #BadBatch character is incoming this month. Crosshair is the obvious one, but who else would make sense?
# Score:  {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'compound': 0.2846}
# ********
# Tweet:  Come check out my first #SWGoH fleet arena climb with Profundity! https://t.co/TUoWx8I0eG
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  @EAHelp errorcode 3.0 on SWGOH, both on tablet and phone.
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  Scythe (hard) Conquest sector 1 feats guide - SWGOH https://t.co/Eo6CeokDor via @YouTube
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  I went 3-6 in this #SWGoH GAC season. My opponents' GP advantage were as follows: +1.7MM, +0.2MM, +0.7MM, +1.1MM, +1.2MM, -0.6MM, +1.1MM, +1.7MM, +1.4MM
# So 3 wins and 3 opponents within 1MM GP of my account. Can't ask for more than that... Except an actual matchmaking system, CG!
# Score:  {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.7419}
# ********
# Tweet:  StarkSG is LIVE!! join us on twitch for SWGOH GAC, strategy discussion, and more! https://t.co/YBkjz6cxW3
# Score:  {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.4724}
# ********
# Tweet:  *Cough cough* let’s do this *cough cough* #SWGoH #swgoh #gaming #SWGOH #twitch #streaming #GAC #swgohgac
#
# https://t.co/PPIqYPJq81
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  After another 2.5 hrs, finally got Profundity 7 star. Thank god that's over! #SWGoH https://t.co/FHJS3Xbzl1
# Score:  {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.5983}
# ********
# Tweet:  Finally unlocked Profundity! If u want it, be prepare for #SWGoH rng 💩 show. Took me 3 hrs to unlock. Now need to do bonus tier... https://t.co/I7LBujoMMv
# Score:  {'neg': 0.0, 'neu': 0.812, 'pos': 0.188, 'compound': 0.6239}
# ********
# Tweet:  JMK Destroys Rey/Dash/Ben Solo with datacron! - SWGOH - Grand arena https://t.co/3umdZmafjw via @YouTube
# Score:  {'neg': 0.23, 'neu': 0.592, 'pos': 0.178, 'compound': -0.2244}
# ********
# Tweet:  StarkSG is LIVE!! join us on twitch for SWGOH GAC, strategy discussion, and more! https://t.co/YBkjz6cxW3
# Score:  {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.4724}
# ********
# Tweet:  @DwarfMaul2 @OGStarwarsAB I'm curious whats SWGOH? I can guess another Star Wars Galaxies emu server but haven't seen that acronym for one yet.
# Score:  {'neg': 0.096, 'neu': 0.835, 'pos': 0.069, 'compound': -0.1655}
# ********
# Tweet:  The next Credit Heist will be 2022-11-01 #swgoh #events https://t.co/7YOfLoJVmr
# Score:  {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.3818}
# ********
# Tweet:  The #GAC it’s super fun when you have to face a guy with almost 4.5 Million GP … thank you @ea_capitalgames @EA please fix the matchmaking 🙏🏻 #SWGoH https://t.co/FXl9kzjebW
# Score:  {'neg': 0.0, 'neu': 0.657, 'pos': 0.343, 'compound': 0.9001}
# ********
# Tweet:  @MLGPROX @AzezelFallen @Diablo And try buy all content to max level is SWGoH or Marvel Strike Force? Disney Mirrorverse have more currencies then Immortal and that is game for children 😅 And we can continue...
# Score:  {'neg': 0.04, 'neu': 0.825, 'pos': 0.135, 'compound': 0.552}
# ********
# Tweet:  @OGStarwarsAB This is actually disgusting. I'm done. I'm gonna keep playing swgoh, battlefront games and reading what I have, but I'm done. Disney can have it.
# Score:  {'neg': 0.14, 'neu': 0.809, 'pos': 0.051, 'compound': -0.34}
# ********
# Tweet:  DarthJJ will be streaming shortly… as soon as I can heat this milk up for a drink 👀
#
# #SWGoH #swgoh #gaming #SWGOH #twitch #streaming #GAC #swgohgac
# https://t.co/PPIqYPJq81 https://t.co/l7MzkZaji1
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  Started up a new section of the site for #SWGoH today - the Best Datacrons. Like them or not, Datacrons are here to stay in #GalaxyOfHeroes so we might as well understand and embrace them! https://t.co/UNvOZ9BYMe
# Score:  {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.8858}
# ********
# Tweet:  Look I know GAC matchmaking isn’t perfect but what the hell is this? @ea_capitalgames @CubsFanHan (obviously I’m the smaller account)
#
# #SWGOH https://t.co/pnbO5Kg6om
# Score:  {'neg': 0.231, 'neu': 0.685, 'pos': 0.085, 'compound': -0.7227}
# ********
# Tweet:  The next credit heist will be Tuesday, 1st November #swgoh #heists
# Score:  {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.3818}
# ********
# Tweet:  The next Credit Heist will be 2022-11-01 #swgoh #events https://t.co/vEnZ3Hs92s
# Score:  {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.3818}
# ********
# Tweet:  The struggle is real! #SWGoH https://t.co/X8MHpAPbR0
# Score:  {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'compound': -0.3802}
# ********
# Tweet:  Star Wars Galaxy of Heroes - Beginner Guide Part 2 - Continue your journ... https://t.co/vLRJ4Ha5Mo via @YouTube #starwars #SWGoH #galaxyofheroes
# Score:  {'neg': 0.164, 'neu': 0.685, 'pos': 0.151, 'compound': -0.0772}
# ********
# Tweet:  StarkSG is LIVE!! join us on twitch for SWGOH GAC, strategy discussion, and more! https://t.co/YBkjz6cxW3
# Score:  {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.4724}
# ********
# Tweet:  RANKING ALL #SWGOH SOLO LEGENDARY TOONS! (Nov 2022) https://t.co/WKJPKqvGn0 via @YouTube
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  @mattapodaca @vicmmic It’s fun. Sort of like a Marvel card game version of Bones from Cult of the Lamb. Not nearly as pay to win as say Marvel Strike or SWGOH.
# Score:  {'neg': 0.037, 'neu': 0.561, 'pos': 0.402, 'compound': 0.9325}
# ********
# Tweet:  RT @Mcmole2: There's a growing problem with hacking/cheating in SWGoH, and it's getting worse.  Breaking down the @bulldog1205 video showin…
# Score:  {'neg': 0.247, 'neu': 0.681, 'pos': 0.072, 'compound': -0.6249}
# ********
# Tweet:  Luminara Omicron!!!! - SWGOH - Is it good? https://t.co/zyOhwrMvq2 via @YouTube
# Score:  {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.6209}
# ********
# Tweet:  Star Wars Galaxy of Heroes - Beginner Guide Part 1 - How to get started ... https://t.co/w2mJgIzpEH via @YouTube #StarWars #SWGoH #galaxyofheroes
# Score:  {'neg': 0.151, 'neu': 0.711, 'pos': 0.138, 'compound': -0.0772}
# ********
# Tweet:  GRAND ARENA MADE ME WANT TO BREAK MY MONITOR! #swgoh https://t.co/UTD91aAI3e
# Score:  {'neg': 0.0, 'neu': 0.598, 'pos': 0.402, 'compound': 0.7234}
# ********
# Tweet:  StarkSG is LIVE!! join us on twitch for SWGOH GAC, strategy discussion, and more! https://t.co/YBkjz6cxW3
# Score:  {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.4724}
# ********
# Tweet:  @Qwik @JHight_Gamer @TheWindstalker Nexus finding another place to consume 😍😍 I need more from Nexus universe - still mobile game variation as SWGoH will be amazing 😍 HotS never die ❤️❤️ Hope announce release dáte for Arclight Rumble 😍
# Score:  {'neg': 0.058, 'neu': 0.774, 'pos': 0.168, 'compound': 0.6747}
# ********
# Tweet:  @Stonekettle SWGOH, F2P, no console needed, building teams based on abilities.
# Score:  {'neg': 0.167, 'neu': 0.682, 'pos': 0.152, 'compound': -0.0516}
# ********
# Tweet:  I took a break from making books to play a bit of #StarWars #swgoh
#
# Enjoy if you’re into this sort of thing.
#
# It’s no secret Darth Vader is my favorite.
#
# https://t.co/pOqJ9msbtI
# Score:  {'neg': 0.063, 'neu': 0.69, 'pos': 0.247, 'compound': 0.7506}
# ********
