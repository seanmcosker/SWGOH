# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
os.environ['TOKEN'] = "AAAAAAAAAAAAAAAAAAAAAAs0ggEAAAAAZa1IS2xF3DqB4kIElAFDyc6oyZM%3DKaJowQh3hk4sqf8b8Lb3DrlffIBE7wDWoTrbTQNrGI4tbaqXRz"

# %%
def auth():
    return os.getenv('TOKEN')

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

def create_url(keyword, max_results = 50):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    #'start_time': start_date,
                    #'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "SWGOH lang:en"
start_time = "2022-01-01T00:00:00.000Z"
end_time = "2021-08-29T00:00:00.000Z"
max_results = 50

# %%
url = create_url(keyword)
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 200

# %%
tweets = []
for i in range((50)):
    try:
        tweets.append(json_response["data"][i]["text"])
    except IndexError:
        break

# %%
tweets
# Out:
# ['The best mods for #DoctorAphra are now live on the site at https://t.co/P7poKJSc8J - I will add BT-1 and try to revise 0-0-0 before the end of the "work" day. #SWGoH',
#  "@GamingFansDFN what happened to the mods part of the webpage? It's down. y'all are the only ones I use for my mods structures. please help. #SWGOH",
#  'My collection in Star Wars Galaxy of Heroes keeps growing. I hear good things about Colonel Starck. #StarWars #SWGOH #MobileGame #collection https://t.co/gwt2XSTfgD',
#  'This is every mobile game ever.\n\nSigned,\nA 7 year SWGOH veteran. https://t.co/F1l8YrYigB',
#  'New year, same old drifting through the galaxy with an unholy alliance in tow.\n\n#SWGOH https://t.co/5zohrUaCJq',
#  'Anyone in #SWGoH need a guild member? I have 5.1mil GP',
#  'Preparing and planning for my 2023 in #SWGoH…\n\nJedi Master Kenobi is the first GL farm for the year, continuing on from last… #DarthKenazSWGoH2023 https://t.co/rSSrzxZH4O',
#  'The next contraband cargo will be Sunday, 8th January #swgoh #heists',
#  'The next Contraband Cargo will be 2023-01-08 #swgoh #events https://t.co/C12JQggUT5',
#  'Hehehe the AAT raid tank lol #SWGoH',
#  'Damn been dealing with a lot last year and my #SWGoH guild dropped me… in all fairness my dad got cancer had to deal with that, now we’re moving my parents into a retirement community dealing with that… but guess I’m a free agent ….  Gp is 5.1mil if anyone need a player?',
#  '@cgouskos You play? Im pretty much super casual on SWGOH now and play this every day. Hit me up in DM so we can party up and do some DMZ. Also play regular with @spartonez and @RonBermudezLA',
#  "@EA Fix the bugs in SWGOH mobile. Or it's more likely we'll be dropping some games.",
#  'I was sitting in my living room watching the Bills game while playing SWGOH on my phone and… holy shit.',
#  "@GoooLezz Me,but just on line gamer. RAID Shadow Legends, because of the beautiful grafics, and SWGOH, 'cause i'm a fan of Star Wars..\n#WarriorNun \n#SaveWarriorNun",
#  'Things I do to keep SWGOH interesting. Anybody else got Heroines Of The Galaxy lined up? Maybe tweak my squads to improve them?\n🤔 There may be enough leftover to have a Jedi squad too.\n\n#swgoh #swgohgungalorians https://t.co/sLG3G4JdEs',
#  "The next Smuggler's Run will be 2023-01-02 #swgoh #events https://t.co/jMykGmK3Eb",
#  "The next Smuggler's Run II will be 2023-01-04 #swgoh #events https://t.co/WoPJLRlBZA",
#  "The next Smuggler's Run will be 2023-01-02 #swgoh #events https://t.co/lcBZ5Bknfh",
#  'so i decided to play another gatcha game besides SWGOH after putting FFBE down for a long time\n\n goddess of victory nikke.\n\naside from the big titty anime robot girls i actually kind of like it. it seems pretty simple',
#  'The next Credit Heist will be 2023-01-03 #swgoh #events https://t.co/7YOfLoJVmr',
#  '@pompomtastic1 I absolutely hate to hear this!  Your podcast was by far my favorite swgoh podcasts. Best wishes going forward',
#  'Less attention thanks to my real life to this #RiseOfTheEmpire Territory Battle in #SWGoH and is it showing in my results. Time to focus in and end this one strong!',
#  'The next Credit Heist will be 2023-01-03 #swgoh #events https://t.co/vEnZ3Hs92s',
#  'The next credit heist will be Tuesday, 3rd January #swgoh #heists',
#  '#SWGoH if interested, I opened up a farming guide sharing server lol\n\nlink is here: https://t.co/eCEHxG0LZb']

# %%
pd.DataFrame(tweets)
# Out:
#                                                     0
# 0   The best mods for #DoctorAphra are now live on...
# 1   @GamingFansDFN what happened to the mods part ...
# 2   My collection in Star Wars Galaxy of Heroes ke...
# 3   This is every mobile game ever.\n\nSigned,\nA ...
# 4   New year, same old drifting through the galaxy...
# 5   Anyone in #SWGoH need a guild member? I have 5...
# 6   Preparing and planning for my 2023 in #SWGoH…\...
# 7   The next contraband cargo will be Sunday, 8th ...
# 8   The next Contraband Cargo will be 2023-01-08 #...
# 9                 Hehehe the AAT raid tank lol #SWGoH
# 10  Damn been dealing with a lot last year and my ...
# 11  @cgouskos You play? Im pretty much super casua...
# 12  @EA Fix the bugs in SWGOH mobile. Or it's more...
# 13  I was sitting in my living room watching the B...
# 14  @GoooLezz Me,but just on line gamer. RAID Shad...
# 15  Things I do to keep SWGOH interesting. Anybody...
# 16  The next Smuggler's Run will be 2023-01-02 #sw...
# 17  The next Smuggler's Run II will be 2023-01-04 ...
# 18  The next Smuggler's Run will be 2023-01-02 #sw...
# 19  so i decided to play another gatcha game besid...
# 20  The next Credit Heist will be 2023-01-03 #swgo...
# 21  @pompomtastic1 I absolutely hate to hear this!...
# 22  Less attention thanks to my real life to this ...
# 23  The next Credit Heist will be 2023-01-03 #swgo...
# 24  The next credit heist will be Tuesday, 3rd Jan...
# 25  #SWGoH if interested, I opened up a farming gu...

# %%
import nltk

#nltk.download("vader_lexicon")

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
vds = SentimentIntensityAnalyzer()
text = tweets[0]

print(text)

print("Sentiment Analysis of text")
print(vds.polarity_scores(text))
# Out:
# The best mods for #DoctorAphra are now live on the site at https://t.co/P7poKJSc8J - I will add BT-1 and try to revise 0-0-0 before the end of the "work" day. #SWGoH
# Sentiment Analysis of text
# {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.6369}

# %%
for i in tweets:
    print("Tweet: ", i)
    print("Score: ", vds.polarity_scores(i))
    print("********")
# Out:
# Tweet:  The best mods for #DoctorAphra are now live on the site at https://t.co/P7poKJSc8J - I will add BT-1 and try to revise 0-0-0 before the end of the "work" day. #SWGoH
# Score:  {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.6369}
# ********
# Tweet:  @GamingFansDFN what happened to the mods part of the webpage? It's down. y'all are the only ones I use for my mods structures. please help. #SWGOH
# Score:  {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.6124}
# ********
# Tweet:  My collection in Star Wars Galaxy of Heroes keeps growing. I hear good things about Colonel Starck. #StarWars #SWGOH #MobileGame #collection https://t.co/gwt2XSTfgD
# Score:  {'neg': 0.126, 'neu': 0.596, 'pos': 0.277, 'compound': 0.5106}
# ********
# Tweet:  This is every mobile game ever.
#
# Signed,
# A 7 year SWGOH veteran. https://t.co/F1l8YrYigB
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  New year, same old drifting through the galaxy with an unholy alliance in tow.
#
# #SWGOH https://t.co/5zohrUaCJq
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  Anyone in #SWGoH need a guild member? I have 5.1mil GP
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  Preparing and planning for my 2023 in #SWGoH…
#
# Jedi Master Kenobi is the first GL farm for the year, continuing on from last… #DarthKenazSWGoH2023 https://t.co/rSSrzxZH4O
# Score:  {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.4648}
# ********
# Tweet:  The next contraband cargo will be Sunday, 8th January #swgoh #heists
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  The next Contraband Cargo will be 2023-01-08 #swgoh #events https://t.co/C12JQggUT5
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  Hehehe the AAT raid tank lol #SWGoH
# Score:  {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.4215}
# ********
# Tweet:  Damn been dealing with a lot last year and my #SWGoH guild dropped me… in all fairness my dad got cancer had to deal with that, now we’re moving my parents into a retirement community dealing with that… but guess I’m a free agent ….  Gp is 5.1mil if anyone need a player?
# Score:  {'neg': 0.083, 'neu': 0.836, 'pos': 0.081, 'compound': 0.2263}
# ********
# Tweet:  @cgouskos You play? Im pretty much super casual on SWGOH now and play this every day. Hit me up in DM so we can party up and do some DMZ. Also play regular with @spartonez and @RonBermudezLA
# Score:  {'neg': 0.0, 'neu': 0.611, 'pos': 0.389, 'compound': 0.9521}
# ********
# Tweet:  @EA Fix the bugs in SWGOH mobile. Or it's more likely we'll be dropping some games.
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  I was sitting in my living room watching the Bills game while playing SWGOH on my phone and… holy shit.
# Score:  {'neg': 0.161, 'neu': 0.759, 'pos': 0.08, 'compound': -0.4215}
# ********
# Tweet:  @GoooLezz Me,but just on line gamer. RAID Shadow Legends, because of the beautiful grafics, and SWGOH, 'cause i'm a fan of Star Wars..
# #WarriorNun
# #SaveWarriorNun
# Score:  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compound': 0.7351}
# ********
# Tweet:  Things I do to keep SWGOH interesting. Anybody else got Heroines Of The Galaxy lined up? Maybe tweak my squads to improve them?
# 🤔 There may be enough leftover to have a Jedi squad too.
#
# #swgoh #swgohgungalorians https://t.co/sLG3G4JdEs
# Score:  {'neg': 0.0, 'neu': 0.785, 'pos': 0.215, 'compound': 0.8299}
# ********
# Tweet:  The next Smuggler's Run will be 2023-01-02 #swgoh #events https://t.co/jMykGmK3Eb
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  The next Smuggler's Run II will be 2023-01-04 #swgoh #events https://t.co/WoPJLRlBZA
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  The next Smuggler's Run will be 2023-01-02 #swgoh #events https://t.co/lcBZ5Bknfh
# Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ********
# Tweet:  so i decided to play another gatcha game besides SWGOH after putting FFBE down for a long time
#
#  goddess of victory nikke.
#
# aside from the big titty anime robot girls i actually kind of like it. it seems pretty simple
# Score:  {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'compound': 0.7947}
# ********
# Tweet:  The next Credit Heist will be 2023-01-03 #swgoh #events https://t.co/7YOfLoJVmr
# Score:  {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.3818}
# ********
# Tweet:  @pompomtastic1 I absolutely hate to hear this!  Your podcast was by far my favorite swgoh podcasts. Best wishes going forward
# Score:  {'neg': 0.142, 'neu': 0.534, 'pos': 0.324, 'compound': 0.6248}
# ********
# Tweet:  Less attention thanks to my real life to this #RiseOfTheEmpire Territory Battle in #SWGoH and is it showing in my results. Time to focus in and end this one strong!
# Score:  {'neg': 0.073, 'neu': 0.754, 'pos': 0.173, 'compound': 0.5594}
# ********
# Tweet:  The next Credit Heist will be 2023-01-03 #swgoh #events https://t.co/vEnZ3Hs92s
# Score:  {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.3818}
# ********
# Tweet:  The next credit heist will be Tuesday, 3rd January #swgoh #heists
# Score:  {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.3818}
# ********
# Tweet:  #SWGoH if interested, I opened up a farming guide sharing server lol
#
# link is here: https://t.co/eCEHxG0LZb
# Score:  {'neg': 0.0, 'neu': 0.57, 'pos': 0.43, 'compound': 0.8074}
# ********
